# %%
# Display graphics inline with the notebook
# %matplotlib notebook

# Standard Python modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import datetime
import requests

# Modules to display images and data tables
from IPython.display import Image
from IPython.core.display import display

WSC_STATIONS = pd.read_pickle('../data/WSC_STATIONS')
WSC_LEVELS = pd.read_pickle('../data/WSC_LEVELS')
WSC_FLOWS = pd.read_pickle('../data/WSC_FLOWS')

# %%
WSC_FLOWS.columns
# Out:
# Index([u'05PA001', u'05PA006', u'05PA012', u'05PB001', u'05PB003', u'05PB004',
#        u'05PB009', u'05PB014', u'05PB015', u'05PB018', u'05PB019', u'05PB020',
#        u'05PB021', u'05PB022', u'05PC009', u'05PC010', u'05PC016', u'05PC018',
#        u'05PC019', u'05PC022'],
#       dtype='object')

# %%
WSC_LEVELS['05PA012'].plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
RR = pd.read_pickle('../data/RR.pkl').plot()

# %%
RL = pd.read_pickle('../data/RR.pkl').plot()
