# %% [markdown]
# # Rule Curves for Rainy and Namakan Lakes

# %% [markdown]
# [2001 Consolidated Order](http://www.ijc.org/files/tinymce/uploaded/2001-01-18_IJC_Order.pdf)

# %%
# Display graphics inline with the notebook
# %matplotlib inline

# Standard Python modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import os
import datetime

# Module to enhance matplotlib plotting
import seaborn
seaborn.set()

# Modules to display images and data tables
from IPython.display import Image
from IPython.core.display import display

# Data Directory
dir = './data/'

# %% [markdown]
# ## <a name=section01></a>1970 Rule Curves for Rainy and Namakan Lakes

# %% [markdown]
# [1970 Rule Curve](http://www.ijc.org/files/tinymce/uploaded/1970-07-29_IJC_Order.pdf)

# %%
# Generic Year to represent data
yr = 2014

# Rainy Lake
RL1970  = {
    datetime.datetime(yr, 1, 1): [1106.6, 1107.1, 1108.1, 1108.6],
    datetime.datetime(yr, 2, 1): [1105.8, 1106.6, 1108.1, 1108.6],
    datetime.datetime(yr, 3, 1): [1105.2, 1106.2, 1108.1, 1108.6],
    datetime.datetime(yr, 4, 1): [1104.6, 1105.6, 1108.1, 1108.6],
    datetime.datetime(yr, 4,21): [1104.6, 1106.2, 1108.1, 1108.6],
    datetime.datetime(yr, 5, 1): [1105.1, 1106.6, 1108.1, 1108.6],
    datetime.datetime(yr, 6, 1): [1106.6, 1107.6, 1108.1, 1108.6],
    datetime.datetime(yr, 7, 1): [1107.4, 1108.1, 1108.1, 1108.6],
    datetime.datetime(yr, 8, 1): [1107.4, 1108.1, 1108.1, 1108.6],
    datetime.datetime(yr, 9, 1): [1107.4, 1108.1, 1108.1, 1108.6],
    datetime.datetime(yr,10, 1): [1107.4, 1108.1, 1108.1, 1108.6],
    datetime.datetime(yr,10,11): [1107.4, 1108.1, 1108.1, 1108.6],
    datetime.datetime(yr,11, 1): [1107.2, 1108.1, 1108.1, 1108.6],
    datetime.datetime(yr,12, 1): [1106.8, 1107.6, 1108.1, 1108.6],
    datetime.datetime(yr,12,31): [1106.4, 1107.1, 1108.1, 1108.6]
}

RL1970 = pd.DataFrame.from_dict(RL1970).transpose()/3.2808
RL1970.columns = ['LRC','URC','EHW','AGO']
RL1970 = RL1970.resample(rule='1D').interpolate()

# Namakan Lake
NL1970 = {    
    datetime.datetime(yr, 1, 1): [1113.6, 1115.3, 1118.6, 1119.1],
    datetime.datetime(yr, 2, 1): [1111.9, 1114.1, 1118.6, 1119.1],
    datetime.datetime(yr, 3, 1): [1110.3, 1113.1, 1118.6, 1119.1],
    datetime.datetime(yr, 4, 1): [1108.6, 1112.0, 1118.6, 1119.1],
    datetime.datetime(yr, 4,21): [1108.6, 1113.1, 1118.6, 1119.1],
    datetime.datetime(yr, 5, 1): [1110.2, 1113.6, 1118.6, 1119.1],
    datetime.datetime(yr, 6, 1): [1115.3, 1116.6, 1118.6, 1119.1],
    datetime.datetime(yr, 6,21): [1117.5, 1118.6, 1118.6, 1119.1],
    datetime.datetime(yr, 7, 1): [1117.6, 1118.6, 1118.6, 1119.1],
    datetime.datetime(yr, 7,21): [1118.0, 1118.6, 1118.6, 1119.1],
    datetime.datetime(yr, 8, 1): [1118.0, 1118.6, 1118.6, 1119.1],
    datetime.datetime(yr, 9, 1): [1118.0, 1118.6, 1118.6, 1119.1],
    datetime.datetime(yr, 9,11): [1118.0, 1118.6, 1118.6, 1119.1],
    datetime.datetime(yr,10, 1): [1117.6, 1118.6, 1118.6, 1119.1],
    datetime.datetime(yr,11, 1): [1116.3, 1117.5, 1118.6, 1119.1],
    datetime.datetime(yr,12, 1): [1115.0, 1116.5, 1118.6, 1119.1],
    datetime.datetime(yr,12,31): [1113.6, 1115.3, 1118.6, 1119.1]
}

NL1970 = pd.DataFrame.from_dict(NL1970).transpose()/3.2808
NL1970.columns = ['LRC','URC','EHW','AGO']
NL1970 = NL1970.resample(rule='1D').interpolate()

# Plot 1970 Rule Curves

plt.hold(True)
plt.plot(NL1970.index,NL1970['EHW'],color='y')
plt.plot(NL1970.index,NL1970['AGO'],'y--')
plt.plot(RL1970.index,RL1970['EHW'],color='y')
plt.plot(RL1970.index,RL1970['AGO'],'y--')

plt.fill_between(NL1970.index,
                 NL1970['LRC'].tolist(),
                 NL1970['URC'].tolist(),
                 color='y',
                 alpha='1')

plt.fill_between(RL1970.index,
                 RL1970['LRC'].tolist(),
                 RL1970['URC'].tolist(),
                 color='y',
                 alpha='1')

plt.ylabel('Lake Level [meters]')
plt.ylim(336,341.5)
plt.title('Rule Curves for Namakan and Rainy Lakes: 1970-2000')
plt.hold(False)

import matplotlib.dates as mdates

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b'))

plt.tight_layout()

# %% [markdown]
# ## <a name=section02></a>2000 Rule Curves for Rainy and Namakan Lakes

# %%
# Namakan Lake

LRC = {
    datetime.datetime(yr, 1, 1): 339.70,
    datetime.datetime(yr, 4, 1): 338.95,
    datetime.datetime(yr, 4,15): 338.95,
    datetime.datetime(yr, 6, 7): 340.70,
    datetime.datetime(yr, 9, 1): 340.45,
    datetime.datetime(yr,10, 1): 340.45,
    datetime.datetime(yr,12,31): 339.70
}

URC = {
    datetime.datetime(yr, 1, 1): 340.00,
    datetime.datetime(yr, 4, 1): 339.70,
    datetime.datetime(yr, 6, 1): 340.95,
    datetime.datetime(yr, 9, 1): 340.65,
    datetime.datetime(yr,10, 1): 340.65,
    datetime.datetime(yr,12,31): 340.00
}

EDL = {
    datetime.datetime(yr, 1, 1): 338.95,
    datetime.datetime(yr, 6,30): 338.95,
    datetime.datetime(yr, 7, 1): 340.15,
    datetime.datetime(yr, 9,30): 340.15,
    datetime.datetime(yr,12,31): 338.95
}

NL2000 = pd.concat([pd.Series(LRC),pd.Series(URC),pd.Series(EDL)], axis=1)
NL2000.columns = ['LRC','URC','EDL']
NL2000 = NL2000.resample(rule='1D').interpolate()

# Rainy Lake

LRC = {
    datetime.datetime(yr, 1, 1): 337.20,
    datetime.datetime(yr, 4, 1): 336.70,
    datetime.datetime(yr, 5, 1): 336.80,
    datetime.datetime(yr, 6, 1): 337.30,
    datetime.datetime(yr, 7, 1): 337.50,
    datetime.datetime(yr, 8,15): 337.50,
    datetime.datetime(yr,12, 1): 337.30,
    datetime.datetime(yr,12,31): 337.20
}

URC = {
    datetime.datetime(yr, 1, 1): 337.45,
    datetime.datetime(yr, 4, 1): 337.00,
    datetime.datetime(yr, 5, 1): 337.40,
    datetime.datetime(yr, 6, 1): 337.60,
    datetime.datetime(yr, 7, 1): 337.75,
    datetime.datetime(yr, 8,15): 337.75,
    datetime.datetime(yr,12, 1): 337.60,
    datetime.datetime(yr,12,31): 337.45
}

EDL = {
    datetime.datetime(yr, 1, 1): 336.90,
    datetime.datetime(yr, 4, 1): 336.70,
    datetime.datetime(yr, 6,30): 336.70,
    datetime.datetime(yr, 7, 1): 337.20,
    datetime.datetime(yr,10,24): 337.20,
    datetime.datetime(yr,12,31): 336.90
}

E

RL2000 = pd.concat([pd.Series(LRC),pd.Series(URC),pd.Series(EDL)], axis=1)
RL2000.columns = ['LRC','URC','EDL']
RL2000 = RL2000.resample(rule='1D').interpolate()

# Plot 2000 Rule Curves

plt.hold('True')
plt.plot(NL2000.index,NL2000['EDL'],color='b')
plt.plot(RL2000.index,RL2000['EDL'],color='b')

plt.fill_between(NL2000.index,
                 NL2000['LRC'].tolist(),
                 NL2000['URC'].tolist(),
                 color='b',
                 alpha='1')

plt.fill_between(RL2000.index,
                 RL2000['LRC'].tolist(),
                 RL2000['URC'].tolist(),
                 color='b',
                 alpha='1')
plt.hold('False')
plt.ylim(336,341.5)
plt.ylabel('Lake Level [meters]')
plt.title('Rule Curves for Namakan and Rainy Lakes: 2000 - present')

import matplotlib.dates as mdates

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b'))

plt.tight_layout()

# %% [markdown]
# ## <a name=section03></a>Graphical Comparison of 1970 and 2000 Rule Curves

# %%
# Plot 1970 Rule Curves

plt.fill_between(NL1970.index,
                 NL1970['LRC'].tolist(),
                 NL1970['URC'].tolist(),
                 color='y', alpha='0.5')

plt.fill_between(RL1970.index,
                 RL1970['LRC'].tolist(),
                 RL1970['URC'].tolist(),
                 color='y', alpha='0.5')

plt.ylabel('Lake Level [meters]')
plt.title('Rule Curves for Namakan and Rainy Lakes: 1970-2000')
plt.tight_layout()

plt.hold('True')
plt.plot(NL2000.index,NL2000['EDL'],color='b')
plt.plot(RL2000.index,RL2000['EDL'],color='b')

plt.fill_between(NL2000.index,
                 NL2000['LRC'].tolist(),
                 NL2000['URC'].tolist(),
                 color='b', alpha='0.5')

plt.fill_between(RL2000.index,
                 RL2000['LRC'].tolist(),
                 RL2000['URC'].tolist(),
                 color='b', alpha='0.5')
plt.hold('False')

plt.ylim(336,341.5)
plt.ylabel('Lake Level [meters]')
plt.title('Comparison of 1970 and 2000 Rule Curves')

import matplotlib.dates as mdates

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b'))

plt.tight_layout()
plt.savefig('./images/RuleCurveComparison.png')

# %% [markdown]
# ## <a name=section04></a>Pickle Rule Curves to Data Files

# %%
dir = './data/'

NL1970.to_pickle(dir+'NL1970.pkl')
RL1970.to_pickle(dir+'RL1970.pkl')

NL2000.to_pickle(dir+'NL2000.pkl')
RL2000.to_pickle(dir+'RL2000.pkl')
